# %% [markdown]
# # Thinking direct battery contro(continuous) No generator.
#
# # Coding in progresss..... Quadratic running cost + Terminal Cost

# %% [markdown]
# # Issue

# %% [markdown]
# To find optimal control at each time step, we have
# $X_t$ = O-U Wind process, $I_t$ = SOC, $dI_t = B_t dt$ $B_t$ = Charge.
# $V(t,X_t,I_t) = inf_{B_t} (X_t+B_t)^2 + V(t+1,X_{t+1},I_t + B_t dt $ where GP approximates $V(t+1)$.
# This is continuous control where we have derivative of GP. To solve FOC, how do we do this? No analytical solution since we dont know $v_{t+1}(\alpha_)$. May be root finding method for FOC.
#
# I can also use NN for optimization...Hmmmmmmmmm

# %%
import numpy as np

from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from scipy.stats import qmc
import sklearn.gaussian_process as gp
# Batch design parameters
sites = 512; batch = 20; nsim = sites * batch

# parameters
 
    
maturity = 24 * 2 # units are in hours
global dt; dt = 15/60;
nstep = int(maturity/dt)
# B and I range
B_min = -6
B_max = 6
I_max = 10
# OU params
alpha = 0.5; m0 = 0; sigma = 2

# %%
t = np.linspace(0,48,nstep+1)

# %%
def demandSimulate(α, m, σ, n_step, n_sim, maturity, P0,given_W = False, W = None):
    
    dt = maturity/n_step
    priceMatrix = np.zeros((n_sim, n_step+1))
    priceMatrix[:,0] = np.ones(n_sim) * P0
    
    if not given_W:
        dW = np.random.normal(0,1,size = (n_sim,n_step) ) * np.sqrt(dt)
    
    else:
        dW = W
    
    
    for i in range(1,n_step+1):
        priceMatrix[:,i] = priceMatrix[:,i-1] + α * (m - priceMatrix[:,i-1]) * dt + σ * dW[:,i-1]
        
    return priceMatrix

# %% [markdown]
# Running cost is quadractic.

# %% [markdown]
# $ dX_t = \alpha (m- X_t)dt +\sigma dt$
# $ dI_t = B_t dt$
#
# $\alpha = 0.5, m = 0, \sigma = 2 $
#
# $I_{max} = 10(kWh), B_{range} = [-6,6]$
#
# T = 48 hours, $\Delta t  = 0.25$hr
# $V(0,I_0,B_0) = E[\int_0^T (B_t+ X_t)^2dt + g(I_T)]$

# %%
from scipy import optimize
from multiprocess import Pool

# %%
def matern_coef(x_new,x_train,l):
    numerator = -5 * (x_new-x_train)/(3*l**2) - 5**(1.5)*(x_new-x_train)*np.abs(x_new-x_train)/(3 * l**3)
    denom     = 1+ np.sqrt(5)*np.abs(x_new-x_train)/l + 5 * (x_new-x_train)**2/(3* l**2)
    return numerator/denom

def partialV_partialI(x_new,x_train,model):
    # To compute the derivative of kernel to differentiate the GP response
    length = model.kernel_.get_params()['length_scale']

    # reshape for single sample 1 row
    y_pred, sigma = model.predict(x_new.reshape(1, -1) ,return_std = True)

    # to store gradient
    y_pred_grad = 0.0;


    # computing k(x,x*)
    k_val= model.kernel_(x_new.reshape(1, -1),x_train,eval_gradient = False).ravel()

    # computing the coeffient of kernel in derivative of kernel
    coef = matern_coef(x_new[1],x_train[:,1],length).ravel()
    # computing kernel derivative as in formula above
    kern_grad = np.multiply(k_val,coef)
    # Get the derivative of response
    f_grad    = np.dot(kern_grad,model.alpha_)
    y_pred_grad = f_grad
    return y_pred_grad

# %% [markdown]
# This is how the loop goes.
#
# ###  (1) Generate Design with N points {$x_{T-1},i_T$} . Create 1 step $x_{T-1} -> x_T$. Note, we will need to repeat {$x_{T-1},i_T$} M times as we will take expectation w.r.t  $X_T$ next step.   Compute $ E(V(X_T,i_T) | x_{T-1})$ by taking average over M observations of $x_{T}$, generated from {$x_{T-1}$}. Fit GP such that $ E(V(X_T,I_T) | x_{T-1})$ is response and $x_{t-1},i_T$ without repitition is input. So, GP is modeling conditional expectation  $ E(V(X_T,i_T) | x_{t-1})$ as a function of $(x_{t-1},i_T)$.
#
# ### (2) Now, generate design {$x_{T-2},i_{T-1}$}  with reptition M times each. Create 1 step $x_{T-2} -> x_{T-1}$. Our goal is $E[V(X_{T-1}, i_{T-1}) | x_{T-2} ]$ and fit GP. First, by DP, $V(x_{T-1}, i_{T-1}) = \min_{b_{T-1}} (i_{T-1} + b_{t-1})^2 + E[V(X_T,i_{T-1} + b_{T-1} dt)| x_{T-1}) =\min_{b_{T-1}} (i_{T-1} + b_{T-1})^2 + GP(x_{T-1},i_{T-1} + b_{T-1} dt)   $ First, 1-D hand optimize for all such $b_{T-1}$, (NM) total.  Plug it back in to get $V(x_{T-1}, i_{T-1})$. But that's not what we want, we want conditional expectations.
#
# ### Now, just like (1), we can compute $E[V(X_{T-1}, i_{T-1}) | x_{T-2} ]$ by taking average (size M),  to get N total $E[V(X_{T-1}, i_{T-1}) | x_{T-2} ]$  and use GP to learn w.r.t input  $(x_{t-2},i_{T-1})$
#
# Repeat until T=0.
#
#
# Note: I don't needanother iteration to optimize each $b_t$,  parallel optimized here.. Also, design points are uniform, can recreate based on $X_t$ distributions and uniform $I_t$. Can get really hudge example 1000 N*1000M = 10**6

# %% [markdown]
# ## Question: To reduce computation, If we skip repeated sampling (hence skip computing conditional expectation) and fit $v(x_T,i_T| x_{T-1}$)with GP, can GP output be interpreted as $E(v(X_T,I_T)| x_{T-1})?$. My thinking is no since GP output is $E(f^* | X,y,x^*)$ where expectation is taken wr.t. density of response $f^* $ or v. and not $X_T$. , so not exactly$ E(v(X_T,I_T)| x_{T-1})$.
#
# ## But when are they equal? $f^*$and $X_T$ have same density and $f^*$ is independent of other data points (X-x,y)  Or simply, conditional densities are same. Not sure if they are. Can we match it?What are they?
#
# ## So, by doing expectation with repeated sampling and fit, we have double conditional expectation and smallest sigma algebra wins, so we have $ E(v(X_T,I_T)| x_{T-1})$
#
# ## Can use another GP to memorize analytically computed B*.Usefu ??? With formulation above, computing response B* is painful since it involes inverting NM matrix.

# %% [markdown]
# # GP and poly issue: At first iterations, preds some are negative. Problematic .
#
# ## GPs are really bad at fitting non negative response! Will give convergence failures and iterrations exceeded. How to solve? Ideas: log transform or very big prior mean. Log transform destroys conditional expectation.In fact, any non-linear transformations.   Aditya have any issue with original paper?
#
#
# ## P.S: Design points of X can  come from it's distribution not Uniform.

# %% [markdown]
# Below is N sites, M reptition for each site.

# %%
def opt(B,X,I,mdl ):

    opt_data = np.array([X,I +B[0]*dt])
    objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
    return objective_func

def minimize(args):
    f,x,i,mdl,lb,ub = args
    bnds = optimize.Bounds(lb, ub )
    res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
    return res.x[0]

sites = 2**9 #(m=9)
batch = 20
sampler = qmc.Sobol(d=2, scramble=False)
# 1024 samples : simple spacde fillling designs
W = sampler.random_base2(m=9)
X_prev = -5+10*W[:,0]; # X0 in [-5,5]
I_next = 10*W[:,1];    # Ic in[0,Imax = 10]

X_prev_rep = np.repeat(X_prev,batch)
I_next_rep = np.repeat(I_next,batch)
#create X_{T-1} to X_T
demandMatrix = demandSimulate(alpha, m0, sigma, 1, len(X_prev_rep), dt, X_prev_rep);
#V_T
finalCost = 200 * np.maximum(5-I_next_rep,0)
# this gives E[V(t+1) | X_t-1 = x_(t-1)]
finalCost = np.mean(finalCost.reshape((batch,sites),order = "F"),axis = 0)

costNext = finalCost;

global Model ; Model = [None] * (nstep)
gpMdl = None


for iStep in range(nstep,0,-1):
    gpMdl = None
    kernel = gp.kernels.Matern( length_scale_bounds=(1e-10, 100000.0),nu=2.5)
    gpMdl = gp.GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=3, alpha=0.5, normalize_y=False)
    X_train = np.column_stack((X_prev, I_next))
    y_train = costNext
    # E[V_t given X_t-1,I_t]
    gpMdl.fit(X_train, y_train)
    
    # assuming we generated, X_t-2,I_t-1
    # create path from X_t-2 to X_t-1, then. we optimize on X_t-1, I_t-1+ Bt dt with V_t to get V_t-1
    demandMatrix = demandSimulate(alpha, m0, sigma, 1, len(X_prev_rep), dt, X_prev_rep);
    
    optimal_B = np.zeros(len(X_prev_rep))
    
    ## Parallel Optimize B* as function of(Xt-1,I)
    LB = np.maximum(B_min, (-I_next_rep)/dt)
    UB = np.minimum(B_max, (I_max-I_next_rep)/dt)
    sample_num = len(X_prev_rep)
    args =[(opt,demandMatrix[i,1],I_next_rep[i],gpMdl,LB[i],UB[i]) for i in range(sample_num)]
    p = Pool()
    optimal_B = np.array(p.map(minimize,args))

    
    
    # this gives B*(X(t-1),I(t-1)) = argmin E[(B(t-1)+X(t-1))**2 + V(t+1,XT, I(t-1)+B(t-1)* dt) | x(t-1)]
    gp_test = np.column_stack((demandMatrix[:,1], I_next_rep + optimal_B *dt))
    costNext = (demandMatrix[:,1]+optimal_B)**2 *dt + gpMdl.predict(gp_test)
    costNext = np.mean(costNext.reshape((batch, sites),order = "F"), axis=0)
        ###
    print(iStep)
    print(  (demandMatrix[:10,1]+optimal_B[:10])**2 *dt )

    print("\n")
    Model[iStep-1] = gpMdl
# Out:
# 192
# [1.06399593 0.43858301 2.35946677 0.88062297 0.48162308 0.61022667
#  1.96898443 0.64935038 0.51181392 0.08713815]
#
#
# 191
# [2.3881432  1.80406978 0.20811694 1.42842842 0.20036726 0.01079092
#  0.02648154 0.33804019 2.16173866 0.03348032]
#
#
# 190
# [6.41775734e-01 5.34260662e-02 2.17252588e-04 2.10251936e-02
#  4.99873329e-01 2.50617285e+00 6.11273825e-01 1.07508868e+00
#  1.07383997e+00 7.14771942e-01]
#
#
# 189
# [1.09850465 0.24730592 1.99336403 0.29303503 1.24340539 1.55970524
#  0.03637976 1.46222888 1.1880425  3.8445187 ]
#
#
# 188
# [0.59369073 1.93177957 0.83893743 0.63262107 0.86029682 0.06733977
#  3.07388776 0.64126733 0.1279878  0.87987377]
#
#
# 187
# [0.29926642 0.14784739 0.12268204 0.12140803 0.2055516  0.26403776
#  0.14738157 0.32920876 0.03117822 1.25729959]
#
#
# 186
# [2.18809478e-01 3.91716020e-05 8.68638906e-02 1.73357974e-02
#  4.00147815e-03 1.49416886e-03 1.50159965e-01 2.74579007e-01
#  5.96045384e-01 2.26693271e-03]
#
#
# 185
# [0.00167152 0.11328894 0.03890285 0.00545778 0.00205489 0.01649936
#  0.02980196 0.03607017 0.58764888 0.18453907]
# Process ForkPoolWorker-4510:
# Process ForkPoolWorker-4511:
# Process ForkPoolWorker-4505:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[96], line 57
#      55 args =[(opt,demandMatrix[i,1],I_next_rep[i],gpMdl,LB[i],UB[i]) for i in range(sample_num)]
#      56 p = Pool()
# ---> 57 optimal_B = np.array(p.map(minimize,args))
#      61 # this gives B*(X(t-1),I(t-1)) = argmin E[(B(t-1)+X(t-1))**2 + V(t+1,XT, I(t-1)+B(t-1)* dt) | x(t-1)]
#      62 gp_test = np.column_stack((demandMatrix[:,1], I_next_rep + optimal_B *dt))
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-4506:
# Process ForkPoolWorker-4508:
# Process ForkPoolWorker-4512:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-4509:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# Process ForkPoolWorker-4507:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 10, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 10, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 10, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 10, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 417, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 307, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 361, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 307, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 361, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 285, in fun_and_grad
#     self._update_fun()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_optimize.py", line 383, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_optimize.py", line 383, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 251, in _update_fun
#     self._update_fun_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 286, in fun_and_grad
#     self._update_grad()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 158, in __init__
#     self._update_fun()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 177, in __init__
#     self._update_grad()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 256, in _update_grad
#     self._update_grad_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 155, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 251, in _update_fun
#     self._update_fun_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 256, in _update_grad
#     self._update_grad_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 155, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 173, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 173, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 10, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 4, in opt
#     objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 505, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 505, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/gaussian_process/_gpr.py", line 404, in predict
#     X = self._validate_data(X, ensure_2d=ensure_2d, dtype=dtype, reset=False)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 4, in opt
#     objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 576, in _dense_difference
#     df = fun(x) - f0
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 576, in _dense_difference
#     df = fun(x) - f0
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 361, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 604, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/gaussian_process/_gpr.py", line 404, in predict
#     X = self._validate_data(X, ensure_2d=ensure_2d, dtype=dtype, reset=False)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 456, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 456, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 286, in fun_and_grad
#     self._update_grad()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/validation.py", line 899, in check_array
#     with warnings.catch_warnings():
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 10, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 604, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 256, in _update_grad
#     self._update_grad_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/warnings.py", line 459, in __enter__
#     if self._entered:
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 4, in opt
#     objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 4, in opt
#     objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 173, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/validation.py", line 967, in check_array
#     n_samples = _num_samples(array)
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 361, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 10, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/gaussian_process/_gpr.py", line 446, in predict
#     V = solve_triangular(
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/gaussian_process/_gpr.py", line 435, in predict
#     K_trans = self.kernel_(X, self.X_train_)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 496, in approx_derivative
#     h, use_one_sided = _adjust_scheme_to_bounds(
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/validation.py", line 352, in _num_samples
#     if isinstance(x.shape[0], numbers.Integral):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 285, in fun_and_grad
#     self._update_fun()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py", line 1687, in __call__
#     X = np.atleast_2d(X)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/linalg/_basic.py", line 346, in solve_triangular
#     x, info = trtrs(a1, b1, overwrite_b=overwrite_b, lower=lower,
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 251, in _update_fun
#     self._update_fun_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/abc.py", line 119, in __instancecheck__
#     return _abc_instancecheck(cls, instance)
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 200, in atleast_2d
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 155, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/abc.py", line 121, in __subclasscheck__
#     def __subclasscheck__(cls, subclass):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/numpy/core/shape_base.py", line 81, in atleast_2d
#     @array_function_dispatch(_atleast_2d_dispatcher)
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
# KeyboardInterrupt
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 4, in opt
#     objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/gaussian_process/_gpr.py", line 446, in predict
#     V = solve_triangular(
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/linalg/_basic.py", line 346, in solve_triangular
#     x, info = trtrs(a1, b1, overwrite_b=overwrite_b, lower=lower,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 361, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 286, in fun_and_grad
#     self._update_grad()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 256, in _update_grad
#     self._update_grad_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 173, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 505, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 576, in _dense_difference
#     df = fun(x) - f0
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 456, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_42386/4041367041.py", line 4, in opt
#     objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/gaussian_process/_gpr.py", line 446, in predict
#     V = solve_triangular(
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/linalg/_basic.py", line 346, in solve_triangular
#     x, info = trtrs(a1, b1, overwrite_b=overwrite_b, lower=lower,
# KeyboardInterrupt
# Process ForkPoolWorker-4516:
# Process ForkPoolWorker-4515:
# Process ForkPoolWorker-4514:
# Process ForkPoolWorker-4513:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 417, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 417, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# # Below is without expectation, treating gp output as cond expectation

# %%
def GP_optimizer(obj_func, initial_theta, bounds):
    theta_opt, func_min, _ = optimize.fmin_l_bfgs_b(obj_func, initial_theta, bounds=bounds)
    return theta_opt, func_min

# %%
# without expectation computation, assumes GP is already expectation
def minimize(args):
    f,x,i,mdl,lb,ub = args
    bnds = optimize.Bounds(lb, ub )
    res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
    return res.x[0]

def opt(B,X,I,mdl ):

    opt_data = np.array([X,I +B[0]*dt])
    objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
    return objective_func
    # Xt process
    
k = 9
sites = 2**9 #(m=9)
batch = 20
sampler = qmc.Sobol(d=2, scramble=False)
# 1024 samples : simple spacde fillling designs
W = sampler.random_base2(m=9)
X_prev = -5+10*W[:,0]; # X0 in [-5,5]
I_next = 10*W[:,1];    # Ic in[0,Imax = 10]

#create X_{T-1} to X_T
demandMatrix = demandSimulate(alpha, m0, sigma, 1, len(X_prev), dt, X_prev);
#V_T
finalCost = 100 * (np.maximum(5-I_next,0) ) 
# this gives E[V(t+1) | X_t-1 = x_(t-1)]

costNext = finalCost;

modelIndx = 0; global Model ; Model = [None] * (nstep)
gpMdl = None
control_Model = [None] * nstep

for iStep in range(nstep,0,-1):
    gpMdl = None
    kernel =gp.kernels.Matern( length_scale_bounds=(1e-10, 100000.0),nu=2.5) 
    gpMdl = gp.GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, alpha=5, optimizer = GP_optimizer)
    X_train = np.column_stack((X_prev, I_next))
    y_train = costNext
    # V_t given X_t-1,I_t
    gpMdl.fit(X_train, y_train)
    
    Model[iStep-1] = gpMdl
        #X_prev = np.random.normal(0,np.sqrt(4*(1- np.exp(-t[iStep-2]))),sites)

        # create path from X_t-2 to X_t-1, then. we optimize on X_t-1, I_t-1+ Bt dt with V_t to get V_t-1
        demandMatrix = demandSimulate(alpha, m0, sigma, 1, len(X_prev), dt, X_prev);

        optimal_B = np.zeros(len(X_prev))


        ## Parallel Optimize B* as function of(Xt-1,I)
        LB = np.maximum(B_min, (-I_next)/dt)
        UB = np.minimum(B_max, (I_max-I_next)/dt)
        sample_num = len(X_prev)
        args =[(opt,demandMatrix[i,1],I_next[i],gpMdl,LB[i],UB[i]) for i in range(sample_num)]
        p = Pool()
        optimal_B = np.array(p.map(minimize,args))
        ###



        # this gives B*(X(t-1),I(t-1)) = argmin E[(B(t-1)+X(t-1))**2 + V(t+1,XT, I(t-1)+B(t-1)* dt) | x(t-1)]
        gp_test = np.column_stack((demandMatrix[:,1], I_next + optimal_B *dt))
        costNext = (demandMatrix[:,1]+optimal_B)**2 *dt + gpMdl.predict(gp_test)



    print(costNext[:5])
    print((demandMatrix[:5,1]+optimal_B[:5])**3 *dt)
    print(iStep)
    print("\n")

# %% [markdown]
# ## Polynomial regresion

# %% [markdown]
# Regression output gives negatve values ...
# Aditya's code same thing

# %%
polyMdl = LinearRegression()

X_train = np.column_stack((X_prev, I_next))
X_poly = poly.fit_transform(X_train)
y_train = finalCost
polyMdl.fit(X_train,y_train)
print(y_train[:10])
polyMdl.predict(X_train)[:10]
# Out:
# [500.    0.  250.    0.  125.    0.  375.    0.  187.5   0. ]
# array([ 3.75730952e+02,  1.24998570e+02,  2.50364803e+02, -3.67663726e-01,
#         1.87681665e+02, -6.30507175e+01,  3.13047899e+02,  6.23154320e+01,
#         2.19023203e+02, -3.17091801e+01])

# %%
from sklearn.linear_model import PoissonRegressor

# %%
def opt(B,X,I,mdl ):

    opt_data = np.array([X,I +B[0]*dt])
    poly = preprocessing.PolynomialFeatures(degree=3)
    opt_data = poly.fit_transform(opt_data.reshape(1,-1))
    objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
    return objective_func

def minimize(args):
    f,x,i,mdl,lb,ub = args
    bnds = optimize.Bounds(lb, ub )
    res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
    return res.x[0]
k = 9
sites = 2**k #(m=9)
batch = 100
sampler = qmc.Sobol(d=2, scramble=False)
# 1024 samples : simple spacde fillling designs
W = sampler.random_base2(m=k)
X_prev = -5+10*W[:,0]; # X0 in [-5,5]
I_next = 10*W[:,1];    # Ic in[0,Imax = 10]

X_prev_rep = np.repeat(X_prev,batch)
I_next_rep = np.repeat(I_next,batch)
#create X_{T-1} to X_T
demandMatrix = demandSimulate(alpha, m0, sigma, 1, len(X_prev_rep), dt, X_prev_rep);
#V_T
finalCost = 200 * np.maximum(5-I_next_rep,0)
# this gives E[V(t+1) | X_t-1 = x_(t-1)]
finalCost = np.mean(finalCost.reshape((batch,sites),order = "F"),axis = 0)

costNext = finalCost;

global Model ; Model = [None] * (nstep)
polyMdl = None


for iStep in range(nstep,0,-1):
    polyMdl = LinearRegression()

    X_train = np.column_stack((X_prev, I_next))
    poly = preprocessing.PolynomialFeatures(degree=3)
    X_poly = poly.fit_transform(X_train)
    
    y_train = costNext
    # E[V_t given X_t-1,I_t]
    polyMdl.fit(X_poly, y_train)

    # assuming we generated, X_t-2,I_t-1
    # create path from X_t-2 to X_t-1, then. we optimize on X_t-1, I_t-1+ Bt dt with V_t to get V_t-1
    demandMatrix = demandSimulate(alpha, m0, sigma, 1, len(X_prev_rep), dt, X_prev_rep);
    
    optimal_B = np.zeros(len(X_prev_rep))
    
    ## Parallel Optimize B* as function of(Xt-1,I)
    LB = np.maximum(B_min, (-I_next_rep)/dt)
    UB = np.minimum(B_max, (I_max-I_next_rep)/dt)
    sample_num = len(X_prev_rep)
    args =[(opt,demandMatrix[i,1],I_next_rep[i],polyMdl,LB[i],UB[i]) for i in range(sample_num)]
    p = Pool()
    optimal_B = np.array(p.map(minimize,args))

    
    
    # this gives B*(X(t-1),I(t-1)) = argmin E[(B(t-1)+X(t-1))**2 + V(t+1,XT, I(t-1)+B(t-1)* dt) | x(t-1)]
    poly_test = np.column_stack((demandMatrix[:,1], I_next_rep + optimal_B *dt))
    poly = preprocessing.PolynomialFeatures(degree=3)
    poly_test = poly.fit_transform(poly_test)
    costNext = (demandMatrix[:,1]+optimal_B)**2 *dt +polyMdl.predict(poly_test)
    costNext = np.mean(costNext.reshape((batch, sites),order = "F"), axis=0)
    print(iStep)
    print(optimal_B[:10])
    print(costNext[:10])
    print( (demandMatrix[:10,1]+optimal_B[:10])**2 *dt )

    print("\n")
    Model[iStep-1] = polyMdl
# Out:
# 192
# [6. 6. 6. 6. 6. 6. 6. 6. 6. 6.]
# [672.69011144  -4.21957274 230.14801376 -38.7359746   76.88081853
#  -39.63258702 427.34825675 -38.71130246 137.03654894 -38.99303028]
# [1.30808146 0.8550176  0.94451147 1.46801167 1.87434702 1.17502408
#  0.02641535 2.29167416 0.19481941 2.0220315 ]
#
#
# 191
# [6. 6. 6. 6. 6. 6. 6. 6. 6. 6.]
# [363.59445468 -30.26992122  86.85548451 -42.33074482  -3.10256826
#  -41.40621646 204.16979901 -44.82030896  19.36582692 -42.52027304]
# [2.31593317 0.86897048 0.00892317 1.60215935 0.5453546  0.13426911
#  1.25465012 0.20266029 1.57748009 0.7360532 ]
#
#
# 190
# [6. 6. 6. 6. 6. 6. 6. 6. 6. 6.]
# [151.57874528 -38.90285003  22.00535217 -39.31649199 -32.99591042
#  -35.44663445  75.98152459 -45.46892166 -31.06840008 -38.55177894]
# [0.20153484 1.88901021 0.18102388 0.21594265 0.41531203 0.38644599
#  1.69621174 0.30617129 0.98262277 1.24080441]
#
#
# 189
# [6. 6. 6. 6. 6. 6. 6. 6. 6. 6.]
# [ 31.88130106 -42.78430571  -4.64882854 -36.2362226  -41.76742391
#  -32.65613747  18.02006133 -43.28420977 -46.33502404 -35.59042071]
# [1.14350828 0.29606847 1.2264962  0.16249398 0.09806872 0.08729345
#  0.7077926  1.93064202 2.77114497 0.10819022]
#
#
# 188
# [6. 6. 6. 6. 6. 6. 6. 6. 6. 6.]
# [-23.11865565 -43.09084041 -12.61683571 -34.63611721 -45.76428752
#  -33.56526407  -6.22281277 -40.02265969 -49.36195708 -35.40783412]
# [0.04992437 0.01596217 1.29764322 0.03446982 0.23293051 0.0073639
#  1.16654245 0.49482225 0.6343672  0.03130675]
#
#
# 187
# [6. 6. 6. 6. 6. 6. 6. 6. 6. 6.]
# [-43.06017767 -42.02100289 -16.07245173 -34.95486118 -45.36852983
#  -33.68493372 -17.92072188 -37.47466363 -48.68728717 -36.36777061]
# [1.61487772e+00 1.37292065e-03 1.14294616e+00 1.24493283e+00
#  1.46991371e+00 1.58618768e-01 4.45747343e-01 4.08849643e+00
#  1.26000538e-01 2.61150547e-02]
#
#
# 186
# [6.         5.56742217 6.         6.         6.         5.97278496
#  33.59807255 35.89222891 30.85469265 29.75804392]
# [0.10606087 0.00858249 0.05528668 0.07168752 0.04422439 0.07111756
#  0.02254947 0.03166531 0.01034691 0.02553402]
#
#
# 6
# [3.40397324 4.02059182 4.21588943 5.06527008 5.23522221 4.89016554
#  4.70179143 3.95511843 3.69445757 3.87668387]
# [31.72907757 30.0235192  35.17807541 35.48021681 30.29268137 30.73439537
#  34.13848678 36.5820238  31.50922432 30.16389895]
# [0.00539644 0.02839457 0.03928629 0.10570662 0.1225584  0.08955527
#  0.07358233 0.02512433 0.01403619 0.02146155]
#
#
# 5
# [4.32089994 4.14311066 3.76517869 3.40723687 3.73035781 5.92649058
#  3.4078501  3.42311698 3.70513718 3.64006553]
# [31.70889311 30.45872515 35.40294724 35.61818629 30.60520824 31.23103627
#  34.71075428 36.64241577 31.74967111 30.48429601]
# [0.04724597 0.03635241 0.01780256 0.00618026 0.01641465 0.20426398
#  0.00619513 0.00657085 0.01544379 0.01307206]
#
#
# 4
# [3.01735008 3.53987929 2.95902704 3.99079459 3.0626466  4.20621135
#  4.23101492 4.52649422 4.33416247 3.65988436]
# [31.99924667 30.76370601 36.50928166 35.44951935 30.90157081 31.653124
#  35.05631177 37.39664345 32.05071199 30.85427876]
# [0.00039236 0.0100293  0.00011509 0.02823558 0.00072056 0.04000038
#  0.04147798 0.06099591 0.04789248 0.0140053 ]
#
#
# 3
# [4.85897318 3.99113769 2.60988921 5.02129932 2.21892885 4.43779573
#  4.80539879 3.34588716 4.48713083 4.11247021]
# [32.55960333 31.16849627 36.75813605 36.80061312 31.25447454 31.82674629
#  35.58270917 37.6613816  32.57595475 31.29712761]
# [0.08285324 0.02878675 0.00086976 0.09570691 0.00781487 0.05342929
#  0.07879231 0.00613857 0.05657426 0.03478506]
#
#
# 2
# [3.49353507 4.30236497 3.74014019 2.88153704 4.08827916 3.92440611
#  3.41579243 3.61268253 3.24705408 1.5837278 ]
# [32.79534408 31.57846052 36.63618395 37.00584418 31.62730628 32.36346572
#  36.31974207 37.73505604 32.51086464 31.49384291]
# [0.0092494  0.04225147 0.01689563 0.0001103  0.03133698 0.02401876
#  0.0072986  0.01266979 0.00384092 0.03228677]
#
#
# 1
# [4.63870182 3.59639164 4.41387156 4.2212562  3.42895903 4.09899576
#  5.57342509 3.88596633 4.40107346 4.81380978]
# [33.32797559 31.89261349 37.59555871 36.95769572 32.03283462 32.56371274
#  36.38298987 37.63180492 33.20390615 31.95749508]
# [0.06189729 0.01255542 0.04823629 0.03782914 0.00804765 0.03185418
#  0.13550407 0.0226304  0.04750769 0.07364756]

# %% [markdown]
# To compute, optimal B, using conditional q estimated by GP + parallel optimization.

# %%
def optimal_V(I0,X0,noise):
    Xs = demandSimulate(alpha, m0, sigma, nstep, 1000, maturity, X0,given_W = True, W = noise)
    Bts = np.zeros((1000,nstep))
    Is = np.zeros((1000,nstep+1))
    Is[:,0] = I0
    imbalance = np.zeros((1000,nstep))
    running_cost = np.zeros((1000,nstep))


    for i in range(nstep):
        ## Parallel Optimize B* as function of(Xt-1,I)
        LB = np.maximum(B_min, (-Is[:,i])/dt)
        UB = np.minimum(B_max, (I_max-Is[:,i])/dt)
        sample_num = len(LB)
        args =[(opt,Xs[idx,i],Is[idx,i],Model[i],LB[idx],UB[idx]) for idx in range(sample_num)]
        p = Pool()
        optimal_B = np.array(p.map(minimize,args))
        ###
        Bts[:,i] = optimal_B
        Is[:,i+1] = Is[:,i]+Bts[:,i]*dt
        imbalance[:,i] = Bts[:,i] +Xs[:,i]
        running_cost[:,i] = (Xs[:,i]+Bts[:,i])**2 *dt 
        #print(i)
    total_running_cost = np.sum(running_cost,axis = 1)
    total_cost = np.mean(total_running_cost+200 * np.maximum(5-Is[:,-1],0))

    return Xs,Is,Bts,imbalance,total_cost, total_running_cost
#noise = np.random.normal(0,1,size = (1000,nstep) ) * np.sqrt(dt)
#X,I,B,imbalance,total_cost,total_running_cost = optimal_V(5,0,noise)

# %%
noise = np.random.normal(0,1,size = (1000,nstep) ) * np.sqrt(dt)
X,I,B,imbalance,total_cost,total_running_cost = optimal_V(5,0,noise)

# %%
total_cost
# Out:
# 105.19812893078503

# %%
X_range = np.arange(-5,5+0.1,0.1)
I_range  = np.arange(0,10+0.1,0.1)

LB = np.maximum(B_min, (-I_range)/dt)
UB = np.minimum(B_max, (I_max-I_range)/dt)
sample_num = len(LB)
opt_ctrl =  np.zeros((len(I_range),len(X_range)))
for i in range(len(X_range)):
    # compute optimization for fix X, all I
    args =[(opt,X_range[i],I_range[idx],Model[0],LB[idx],UB[idx]) for idx in range(sample_num)]
    p = Pool()
    optimal_B = np.array(p.map(minimize,args))
    opt_ctrl[:,i] = optimal_B
# Out:
# Process ForkPoolWorker-62743:
# Process ForkPoolWorker-62736:
# Process ForkPoolWorker-62737:
# Process ForkPoolWorker-62740:
# Process ForkPoolWorker-62739:
# Process ForkPoolWorker-62738:
# Process ForkPoolWorker-62741:
# Process ForkPoolWorker-62742:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 417, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
X_range = np.arange(-5,5+0.1,0.1)
I_range  = np.arange(0,10+0.1,0.1)
noise = np.random.normal(0,1,size = (1000,nstep) ) * np.sqrt(dt)
total_cost = np.zeros((len(I_range),len(X_range)))

for i in range(len(X_range)):
    for j in range(len(I_range)):
        total_cost[j,i] = optimal_V(I_range[j],X_range[i],noise)[4]
        #opt_ctrl[j,i] = control_Model[0].predict(np.array([X_range[i],I_range[j]]).reshape(1,-1))
        #lower_b = np.maximum(B_min, (-I_range[j])/dt)
        #upper_b = np.minimum(B_max, (I_max-I_range[i])/dt)
        #opt_ctrl[j,i] = np.minimum(opt_ctrl[j,i],upper_b)
        #opt_ctrl[j,i]= np.maximum(opt_ctrl[j,i],lower_b)
        print("Cost: " + str(total_cost[j,i]))
# Out:
# Cost: 108.69457792159076
# Cost: 108.82768164928585
# Cost: 108.96298637561083
# Cost: 109.10263671491346
# Cost: 109.24404781265874
# Cost: 109.38797994310482
# Cost: 109.53629494009778
# Cost: 109.6856123983952
# Cost: 109.83865942548665
# Cost: 109.99434239097798
# Cost: 110.15310067401813
# Cost: 110.31793189344879
# Cost: 110.48801781864452
# Cost: 110.66046521659344
# Cost: 128.8620596951131
# Cost: 129.42120382427726
# Cost: 130.05014673162913
# Cost: 130.52910405246593
# Cost: 130.90910405246592
# Cost: 131.36910405246593
# Cost: 131.90910405246592
# Cost: 132.52910405246593
# Cost: 133.22910405246594
# Cost: 134.00910405246594
# Cost: 106.68047318775754
# Cost: 106.75996565269016
# Cost: 106.84171663051961
# Cost: 106.92675954854462
# Cost: 107.0140279867488
# Cost: 107.10362355908002
# Cost: 107.1961410684666
# Cost: 107.290818360218
# Cost: 107.39001129761121
# Cost: 107.492566897982
# Cost: 107.5988773109379
# Cost: 107.70596686248359
# Cost: 107.81435838971022
# Cost: 107.92543173775316
# Cost: 108.04010917749758
# Cost: 108.15720864883896
# Cost: 108.2769163262597
# Cost: 108.40061448484902
# Cost: 108.52846252523939
# Cost: 108.65828734483017
# Cost: 108.79253286140869
# Cost: 108.92734799272279
# Cost: 109.06519411795243
# Cost: 109.20638916408377
# Cost: 109.3524292228839
# Cost: 109.50119354357258
# Cost: 109.65325703496545
# Cost: 109.80958815292458
# Cost: 109.9676000230388
# Cost: 110.12807594891053
# Process ForkPoolWorker-1660912:
# Process ForkPoolWorker-1660918:
# Process ForkPoolWorker-1660917:
# Process ForkPoolWorker-1660913:
# Process ForkPoolWorker-1660915:
# Process ForkPoolWorker-1660919:
# Process ForkPoolWorker-1660914:
# Process ForkPoolWorker-1660916:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[208], line 8
#       6 for i in range(len(X_range)):
#       7     for j in range(len(I_range)):
# ----> 8         total_cost[j,i] = optimal_V(I_range[j],X_range[i],noise)[4]
#       9         #opt_ctrl[j,i] = control_Model[0].predict(np.array([X_range[i],I_range[j]]).reshape(1,-1))
#      10         #lower_b = np.maximum(B_min, (-I_range[j])/dt)
#      11         #upper_b = np.minimum(B_max, (I_max-I_range[i])/dt)
#      12         #opt_ctrl[j,i] = np.minimum(opt_ctrl[j,i],upper_b)
#      13         #opt_ctrl[j,i]= np.maximum(opt_ctrl[j,i],lower_b)
#      14         print("Cost: " + str(total_cost[j,i]))
#
# Cell In[192], line 17, in optimal_V(I0, X0, noise)
#      15 args =[(opt,Xs[idx,i],Is[idx,i],Model[i],LB[idx],UB[idx]) for idx in range(sample_num)]
#      16 p = Pool()
# ---> 17 optimal_B = np.array(p.map(minimize,args))
#      18 ###
#      19 Bts[:,i] = optimal_B
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/energy_mike/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 12, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 12, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 12, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 12, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 12, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 12, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 12, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 530, in minimize
#     x0 = np.atleast_1d(np.asarray(x0))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 12, in minimize
#     res = optimize.minimize(f, x0=(lb+ub)/2, args=(x,i,mdl),method = "L-BFGS-B", bounds = bnds)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 279, in _minimize_lbfgsb
#     x0 = asarray(x0).ravel()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 361, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "<__array_function__ internals>", line 180, in atleast_1d
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 361, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 307, in _minimize_lbfgsb
#     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 294, in _minimize_lbfgsb
#     if (new_bounds[0] > new_bounds[1]).any():
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_minimize.py", line 710, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/numpy/core/shape_base.py", line 19, in _atleast_1d_dispatcher
#     def _atleast_1d_dispatcher(*arys):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 285, in fun_and_grad
#     self._update_fun()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 395, in _minimize_lbfgsb
#     hess_inv = LbfgsInvHessProduct(s[:n_corrs], y[:n_corrs])
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 286, in fun_and_grad
#     self._update_grad()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/numpy/core/_methods.py", line 55, in _any
#     def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 361, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_optimize.py", line 383, in _prepare_scalar_function
#     sf = ScalarFunction(fun, x0, args, grad, hess,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py", line 441, in __init__
#     self.rho = 1 / np.einsum('ij,ij->i', sk, yk)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 251, in _update_fun
#     self._update_fun_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 256, in _update_grad
#     self._update_grad_impl()
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 177, in __init__
#     self._update_grad()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 285, in fun_and_grad
#     self._update_fun()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 155, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "<__array_function__ internals>", line 200, in einsum
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 173, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 256, in _update_grad
#     self._update_grad_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 251, in _update_fun
#     self._update_fun_impl()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1009, in einsum
#     @array_function_dispatch(_einsum_dispatcher, module='numpy')
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 505, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 173, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 155, in update_fun
#     self.f = fun_wrapped(self.x)
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 576, in _dense_difference
#     df = fun(x) - f0
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 6, in opt
#     objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 505, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 456, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/linear_model/_base.py", line 386, in predict
#     return self._decision_function(X)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 576, in _dense_difference
#     df = fun(x) - f0
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 5, in opt
#     opt_data = poly.fit_transform(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/linear_model/_base.py", line 367, in _decision_function
#     check_is_fitted(self)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_numdiff.py", line 456, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 5, in opt
#     opt_data = poly.fit_transform(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1405, in check_is_fitted
#     def check_is_fitted(estimator, attributes=None, *, msg=None, all_or_any=all):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py", line 137, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 915, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
# KeyboardInterrupt
#   File "/var/folders/7r/vg_dkm797ln94m896r7lm9c40000gn/T/ipykernel_64045/3140775455.py", line 6, in opt
#     objective_func = (X+B[0])**2 *dt + mdl.predict(opt_data.reshape(1,-1))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 915, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/linear_model/_base.py", line 386, in predict
#     return self._decision_function(X)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/linear_model/_base.py", line 369, in _decision_function
#     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/preprocessing/_polynomial.py", line 322, in fit
#     _, n_features = self._validate_data(X, accept_sparse=True).shape
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 75, in validate_parameter_constraints
#     if constraint.is_satisfied_by(param_val):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 604, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 590, in is_satisfied_by
#     if isinstance(val, Integral) and not isinstance(val, bool):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/base.py", line 604, in _validate_data
#     out = check_array(X, input_name="X", **check_params)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/validation.py", line 959, in check_array
#     _assert_all_finite(
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/abc.py", line 119, in __instancecheck__
#     return _abc_instancecheck(cls, instance)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/validation.py", line 959, in check_array
#     _assert_all_finite(
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/validation.py", line 112, in _assert_all_finite
#     if not xp.isdtype(X.dtype, ("real floating", "complex floating")):
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 283, in isdtype
#     return isdtype(dtype, kind, xp=self)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/validation.py", line 120, in _assert_all_finite
#     first_pass_isfinite = xp.isfinite(xp.sum(X))
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 82, in isdtype
#     return any(_isdtype_single(dtype, k, xp=xp) for k in kind)
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 227, in __getattr__
#     def __getattr__(self, name):
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 82, in <genexpr>
#     return any(_isdtype_single(dtype, k, xp=xp) for k in kind)
# KeyboardInterrupt
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 101, in _isdtype_single
#     return dtype in {xp.float32, xp.float64}
#   File "/Users/taung/miniconda3/envs/energy_mike/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 227, in __getattr__
#     def __getattr__(self, name):
# KeyboardInterrupt

# %%
X, Y = np.meshgrid(X_range, I_range)
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection='3d') 
ax.plot_surface(X, Y, total_cost, cmap='cool', alpha=0.8)
ax.set_title('optimal_value V(0,I0,demand) ', fontsize=14)
ax.view_init(30, 30)
ax.set_xlabel('demand', fontsize=12)
ax.set_ylabel('I0', fontsize=12)
ax.set_zlabel('V', fontsize=12)
plt.show()

# %%
X, Y = np.meshgrid(X_range, I_range)

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection='3d') 
ax.plot_surface(X, Y, opt_ctrl, cmap='cool', alpha=0.8)
ax.set_title('optimal_control B(I,Demand) (Poly) ', fontsize=14)
ax.set_xlabel('demand', fontsize=12)
ax.view_init(30, 60)
ax.set_ylabel('I0', fontsize=12)
ax.set_zlabel('V', fontsize=12)
plt.show()

# %% [markdown]
# # Below GP has error. We didn't model for demand >0 by bug. On top of optimization errors.

# %%
X, Y = np.meshgrid(X_range, I_range)

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection='3d') 
ax.plot_surface(X, Y, opt_ctrl, cmap='cool', alpha=0.8)
ax.set_title('optimal_control B(I,Demand) ', fontsize=14)
ax.set_xlabel('demand', fontsize=12)
ax.view_init(30, 60)
ax.set_ylabel('I0', fontsize=12)
ax.set_zlabel('V', fontsize=12)
plt.show()

# %%
noise = np.random.normal(0,1,size = (1000,nstep) ) * np.sqrt(dt)
X,I,B,imbalance,cost_,total_running_cost = optimal_V(5,0,noise)

# %%
import matplotlib.pyplot as plt
t = np.linspace(0,48,192)
plt.plot(t,B[100,:])
plt.plot(t,X[100,:-1])
plt.xlabel("Time(hr)")
plt.ylabel("kW")
plt.legend(["Battery Power","Wind Demand" ])

# %%
plt.plot(t,I[100,:-1])
plt.plot(t,imbalance[100,:])
plt.xlabel("Time(hr)")

plt.legend(["SOC","Residual after optimizing " ])
plt.plot()
# Out:
# []

# %%
from scipy.optimize import minimize,Bounds


    
idx = np.random.randint(low = 0, high = 2**9)
X,I = demandMatrix[idx,1],I_next[idx]
lower_b = np.maximum(B_min, (-I)/dt)
upper_b = np.minimum(B_max, (I_max-I)/dt)
initial_guess = (lower_b+upper_b)/2
bnds = Bounds(lb=lower_b, ub = upper_b)
print(bnds)
print(X,I)
# gradient is necessary for better estimates
result = optimize.minimize(opt, x0=initial_guess, args=(X,I,Model[0]),method = "L-BFGS-B", bounds = bnds)
result.x
# Out:
# Bounds(array([-6.]), array([6.]))
# 0.7402206515068162 1.8359375
# array([-0.15790234])

# %%
    
idx = np.random.randint(low = 0, high = 2**9)
X,I = demandMatrix[idx,1],I_next[idx]
lower_b = np.maximum(B_min, (-I)/dt)
upper_b = np.minimum(B_max, (I_max-I)/dt)
initial_guess = (lower_b+upper_b)/2
bnds = Bounds(lb=lower_b, ub = upper_b)
print(bnds)
# gradient is necessary for better estimates
result = optimize.minimize(opt, x0=initial_guess,  args=(X,I,Model[0]),method = "L-BFGS-B", bounds = bnds)
print(result.x)
print(X,I)
B_range = np.linspace(lower_b,upper_b,100)
Vs = np.ones(len(B_range))
for i in range(len(B_range)):
    Vs[i] = opt([B_range[i]],X,I,Model[0])
plt.plot(B_range,Vs)
# Out:
# Bounds(array([-2.03125]), array([6.]))
# [0.54020279]
# 0.05652253378498349 0.5078125

# %%
    
idx = np.random.randint(low = 0, high = 2**9)
X,I = demandMatrix[idx,1],I_next[idx]
lower_b = np.maximum(B_min, (-I)/dt)
upper_b = np.minimum(B_max, (I_max-I)/dt)
initial_guess = (lower_b+upper_b)/2
bnds = Bounds(lb=lower_b, ub = upper_b)
print(bnds)
# gradient is necessary for better estimates
result = minimize(opt, x0=initial_guess,  args=(X,I,Model[0]),method = "L-BFGS-B", bounds = bnds)
print(result.x)
print(X,I)
B_range = np.linspace(lower_b,upper_b,100)
Vs = np.ones(len(B_range))
for i in range(len(B_range)):
    Vs[i] = opt([B_range[i]],X,I,Model[0])
plt.plot(B_range,Vs)
# Out:
# Bounds(array([-6.]), array([6.]))
# [1.95618315]
# -2.188887550143126 8.046875

# %%
    
idx = np.random.randint(low = 0, high = 2**10)
X,I = demandMatrix[idx,1],I_next[idx]
lower_b = np.maximum(B_min, (-I)/dt)
upper_b = np.minimum(B_max, (I_max-I)/dt)
initial_guess = (lower_b+upper_b)/2
bnds = Bounds(lb=lower_b, ub = upper_b)
print(bnds)
# gradient is necessary for better estimates
result = minimize(opt, x0=initial_guess, args=(X,I),method = "L-BFGS-B", bounds = bnds)
print(result.x)
print(X,I)
B_range = np.linspace(lower_b,upper_b,100)
Vs = np.ones(len(B_range))
for i in range(len(B_range)):
    Vs[i] = opt([B_range[i]],X,I)
plt.plot(B_range,Vs)

# %%
    
idx = np.random.randint(low = 0, high = 2**9)
X,I = demandMatrix[idx,1],I_next[idx]
lower_b = np.maximum(B_min, (-I)/dt)
upper_b = np.minimum(B_max, (I_max-I)/dt)
initial_guess = (lower_b+upper_b)/2
bnds = Bounds(lb=lower_b, ub = upper_b)
print(bnds)
# gradient is necessary for better estimates
result = minimize(opt, x0=initial_guess,  args=(X,I,Model[0]),method = "L-BFGS-B", bounds = bnds)
print(result.x)
print(X,I)
B_range = np.linspace(lower_b,upper_b,100)
Vs = np.ones(len(B_range))
for i in range(len(B_range)):
    Vs[i] = opt([B_range[i]],X,I,Model[0])
plt.plot(B_range,Vs)
# Out:
# Bounds(array([-6.]), array([6.]))
# [-0.04710944]
# -0.2781361689504437 6.1328125

# %%
    
idx = np.random.randint(low = 0, high = 2**9)
X,I = demandMatrix[idx,1],I_next[idx]
lower_b = np.maximum(B_min, (-I)/dt)
upper_b = np.minimum(B_max, (I_max-I)/dt)
initial_guess = (lower_b+upper_b)/2
bnds = Bounds(lb=lower_b, ub = upper_b)
print(bnds)
# gradient is necessary for better estimates
result = minimize(opt, x0=initial_guess,  args=(X,I,Model[0]),method = "L-BFGS-B", bounds = bnds)
print(result.x)
print(X,I)
B_range = np.linspace(lower_b,upper_b,100)
Vs = np.ones(len(B_range))
for i in range(len(B_range)):
    Vs[i] = opt([B_range[i]],X,I,Model[0])
plt.plot(B_range,Vs)
# Out:
# Bounds(array([-6.]), array([6.]))
# [2.183911]
# -2.565224977844152 4.140625

# %%
    
idx = np.random.randint(low = 0, high = 2**9)
X,I = demandMatrix[idx,1],I_next[idx]
lower_b = np.maximum(B_min, (-I)/dt)
upper_b = np.minimum(B_max, (I_max-I)/dt)
initial_guess = (lower_b+upper_b)/2
bnds = Bounds(lb=lower_b, ub = upper_b)
print(bnds)
# gradient is necessary for better estimates
result = minimize(opt, x0=initial_guess,  args=(X,I,Model[0]),method = "L-BFGS-B", bounds = bnds)
print(result.x)
print(X,I)
B_range = np.linspace(lower_b,upper_b,100)
Vs = np.ones(len(B_range))
for i in range(len(B_range)):
    Vs[i] = opt([B_range[i]],X,I,Model[0])
plt.plot(B_range,Vs)
# Out:
# Bounds(array([-6.]), array([6.]))
# [4.58801004]
# -4.810302672777251 7.94921875
